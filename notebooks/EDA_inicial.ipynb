# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

# Carpeta de notebooks
ruta_proyecto = os.path.abspath("..")
print("Ruta proyecto:", ruta_proyecto)

# Listar todo lo que tiene
print("Contenido de proyecto_final:")
print(os.listdir(ruta_proyecto))
# Out:
# Ruta proyecto: c:\Users\ffmma\OneDrive\Desktop\proyecto_final
# Contenido de proyecto_final:
# ['.git', '.gitignore', 'data', 'notebooks', 'README.md', 'src']

# %%
import os

ruta_data = os.path.join("..", "data")
print("Contenido de data/:")
print(os.listdir(ruta_data))
# Out:
# Contenido de data/:
# ['data_raw']

# %%
# Carpeta donde están los archivos
ruta_data_raw = os.path.join("..", "data", "data_raw")
ruta_data_raw
# Out:
# '..\\data\\data_raw'

# %%
archivo1 = os.path.join(ruta_data_raw, "telecom_clients_us.csv")

df1 = pd.read_csv(archivo1)

df1
# Out:
#      user_id tariff_plan  date_start
# 0     166713           A  2019-08-15
# 1     166901           A  2019-08-23
# 2     168527           A  2019-10-29
# 3     167097           A  2019-09-01
# 4     168193           A  2019-10-16
# ..       ...         ...         ...
# 727   166554           B  2019-08-08
# 728   166911           B  2019-08-23
# 729   167012           B  2019-08-28
# 730   166867           B  2019-08-22
# 731   166565           B  2019-08-08
#
# [732 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      732 non-null    int64
#  1   tariff_plan  732 non-null    object
#  2   date_start   732 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 17.3+ KB

# %%
#cambio de tipos de la columna date_start de objetct a datetime 
df1["date_start"]=pd.to_datetime(df1["date_start"], errors="coerce")

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      732 non-null    int64
#  1   tariff_plan  732 non-null    object
#  2   date_start   732 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
#chequo de valores nulos
df1.isnull().sum()
#ninguna columna tiene valores nulos
# Out:
# user_id        0
# tariff_plan    0
# date_start     0
# dtype: int64

# %%
df1.head()
# Out:
#    user_id tariff_plan date_start
# 0   166713           A 2019-08-15
# 1   166901           A 2019-08-23
# 2   168527           A 2019-10-29
# 3   167097           A 2019-09-01
# 4   168193           A 2019-10-16

# %%
archivo2 = os.path.join(ruta_data_raw, "telecom_dataset_us.csv")

df2 = pd.read_csv(archivo2)

df2.head()
# Out:
#    user_id                       date direction internal  operator_id  \
# 0   166377  2019-08-04 00:00:00+03:00        in    False          NaN
# 1   166377  2019-08-05 00:00:00+03:00       out     True     880022.0
# 2   166377  2019-08-05 00:00:00+03:00       out     True     880020.0
# 3   166377  2019-08-05 00:00:00+03:00       out     True     880020.0
# 4   166377  2019-08-05 00:00:00+03:00       out    False     880022.0
#
#    is_missed_call  calls_count  call_duration  total_call_duration
# 0            True            2              0                    4
# 1            True            3              0                    5
# 2            True            1              0                    1
# 3           False            1             10                   18
# 4            True            3              0                   25

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53902 entries, 0 to 53901
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              53902 non-null  int64
#  1   date                 53902 non-null  object
#  2   direction            53902 non-null  object
#  3   internal             53785 non-null  object
#  4   operator_id          45730 non-null  float64
#  5   is_missed_call       53902 non-null  bool
#  6   calls_count          53902 non-null  int64
#  7   call_duration        53902 non-null  int64
#  8   total_call_duration  53902 non-null  int64
# dtypes: bool(1), float64(1), int64(4), object(3)
# memory usage: 3.3+ MB

# %%
df2.sample(10)
# Out:
#        user_id                       date direction internal  operator_id  \
# 47372   168187  2019-10-22 00:00:00+03:00        in    False     937708.0
# 41721   167888  2019-11-05 00:00:00+03:00       out    False     928888.0
# 35896   167545  2019-11-22 00:00:00+03:00       out     True     964510.0
# 29735   167264  2019-10-12 00:00:00+03:00        in    False          NaN
# 12981   166782  2019-10-04 00:00:00+03:00       out    False     893804.0
# 43187   167977  2019-11-20 00:00:00+03:00       out    False     944220.0
# 44863   168062  2019-11-12 00:00:00+03:00       out    False     952392.0
# 24412   167109  2019-11-22 00:00:00+03:00       out     True     909910.0
# 28328   167180  2019-10-07 00:00:00+03:00        in    False     905930.0
# 49347   168187  2019-11-25 00:00:00+03:00        in    False     948286.0
#
#        is_missed_call  calls_count  call_duration  total_call_duration
# 47372           False            9           1089                 1159
# ...

# %%
#cambio a datetime de la columna operator_id
df2["date"]= pd.to_datetime(df2["date"],errors = "coerce")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53902 entries, 0 to 53901
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              53902 non-null  int64
#  1   date                 53902 non-null  datetime64[ns, UTC+03:00]
#  2   direction            53902 non-null  object
#  3   internal             53785 non-null  object
#  4   operator_id          45730 non-null  float64
#  5   is_missed_call       53902 non-null  bool
#  6   calls_count          53902 non-null  int64
#  7   call_duration        53902 non-null  int64
#  8   total_call_duration  53902 non-null  int64
# dtypes: bool(1), datetime64[ns, UTC+03:00](1), float64(1), int64(4), object(2)
# memory usage: 3.3+ MB

# %%
#extracción de fecha y horas de la columna date
df2["date"] = df2["date"].dt.date

df2
# Out:
#        user_id        date direction internal  operator_id  is_missed_call  \
# 0       166377  2019-08-04        in    False          NaN            True
# 1       166377  2019-08-05       out     True     880022.0            True
# 2       166377  2019-08-05       out     True     880020.0            True
# 3       166377  2019-08-05       out     True     880020.0           False
# 4       166377  2019-08-05       out    False     880022.0            True
# ...        ...         ...       ...      ...          ...             ...
# 53897   168606  2019-11-10       out     True     957922.0            True
# 53898   168606  2019-11-11       out     True     957922.0           False
# 53899   168606  2019-11-15       out     True     957922.0           False
# 53900   168606  2019-11-15       out     True     957922.0           False
# 53901   168606  2019-11-19        in    False          NaN            True
#
#        calls_count  call_duration  total_call_duration
# ...

# %%
#checar valores nulos
df2.isnull().sum()
# Out:
# user_id                   0
# date                      0
# direction                 0
# internal                117
# operator_id            8172
# is_missed_call            0
# calls_count               0
# call_duration             0
# total_call_duration       0
# dtype: int64

# %% [markdown]
# En la columna internal se puede ver que solo hay 117 valores nulos, concidero que es una buena opción mantener estos ya que se puede también analizar si la falta de registro lleva algún patrón.

# %% [markdown]
# La columna presenta un total de 8172 valores nulos, esto lo encuentro un poco preocupante ya que el principal objetivo es valorar el desempeño de los trabajadores.
# Considero que una buena opción para este caso cambiarlos por un valor "0", más adelante podrían ser huzados para poder mostrar la cantidad de llamadas con un operador sin id, para no perder datos y mantener un volumen aunque no se pueda identificar al operador.

# %%
#convertí Nan a 0 
df2["operator_id"] = df2["operator_id"].fillna("Unknown")

df2.sample(5)
# Out:
#        user_id        date direction internal operator_id  is_missed_call  \
# 1691    166405  2019-11-24       out    False    939474.0           False
# 20291   167002  2019-09-11       out    False    900492.0           False
# 24630   167112  2019-09-30        in    False     Unknown            True
# 21632   167035  2019-11-05        in    False    923528.0           False
# 16423   166916  2019-10-14       out     True    906400.0           False
#
#        calls_count  call_duration  total_call_duration
# 1691            11           1007                 1196
# 20291            1             18                   48
# 24630            4              0                   25
# 21632            2            139                  183
# 16423            6            181                  209

# %%
#hacer los float a int
df2["operator_id"] = df2["operator_id"].apply(
    lambda x: int(float(x)) if str(x).replace('.', '', 1).isdigit() else "Unknown"
)

df2.sample(10)
# Out:
#        user_id        date direction internal operator_id  is_missed_call  \
# 26353   167150  2019-10-25        in    False      905564           False
# 30154   167285  2019-10-15       out    False      908640           False
# 26457   167150  2019-11-05        in    False      905564           False
# 11081   166680  2019-11-28       out    False      917234           False
# 13250   166782  2019-10-29       out    False      900180           False
# 29270   167235  2019-10-09        in    False      913788           False
# 5369    166520  2019-10-02       out    False      884946            True
# 16562   166916  2019-10-22        in    False      906410           False
# 21897   167052  2019-10-04        in    False     Unknown            True
# 36123   167580  2019-10-30       out    False      936382           False
#
#        calls_count  call_duration  total_call_duration
# 26353            2            334                  377
# ...

# %%
df2.head()
# Out:
#    user_id        date direction internal operator_id  is_missed_call  \
# 0   166377  2019-08-04        in    False     Unknown            True
# 1   166377  2019-08-05       out     True      880022            True
# 2   166377  2019-08-05       out     True      880020            True
# 3   166377  2019-08-05       out     True      880020           False
# 4   166377  2019-08-05       out    False      880022            True
#
#    calls_count  call_duration  total_call_duration
# 0            2              0                    4
# 1            3              0                    5
# 2            1              0                    1
# 3            1             10                   18
# 4            3              0                   25

# %% [markdown]
# ## Anlisis exploratorio (EDA)

# %%
#Resumen estadístico 
df1.describe(include="all")
# Out:
#               user_id tariff_plan                     date_start
# count      732.000000         732                            732
# unique            NaN           3                            NaN
# top               NaN           C                            NaN
# freq              NaN         395                            NaN
# mean    167431.927596         NaN  2019-09-14 16:39:20.655737600
# min     166373.000000         NaN            2019-08-01 00:00:00
# 25%     166900.750000         NaN            2019-08-23 00:00:00
# 50%     167432.000000         NaN            2019-09-16 00:00:00
# 75%     167973.000000         NaN            2019-10-08 00:00:00
# max     168606.000000         NaN            2019-10-31 00:00:00
# std        633.810383         NaN                            NaN

# %% [markdown]
# Resumen estadístico general df1
# #
# Los identificadores de usuarios están completos, con todos los IDs caen dentro de un rángo que es lógico. La mayoría de los usuarios se encuentran en el plan C. Los ususarios se distribuyen de manera continua entre agosto y octubre de 2019.

# %%
df2.describe(include="all")
# Out:
#               user_id        date direction internal operator_id  \
# count    53902.000000       53902     53902    53785       53902
# unique            NaN         119         2        2        1093
# top               NaN  2019-11-25       out    False     Unknown
# freq              NaN        1220     31917    47621        8172
# mean    167295.344477         NaN       NaN      NaN         NaN
# std        598.883775         NaN       NaN      NaN         NaN
# min     166377.000000         NaN       NaN      NaN         NaN
# 25%     166782.000000         NaN       NaN      NaN         NaN
# 50%     167162.000000         NaN       NaN      NaN         NaN
# 75%     167819.000000         NaN       NaN      NaN         NaN
# max     168606.000000         NaN       NaN      NaN         NaN
#
#        is_missed_call   calls_count  call_duration  total_call_duration
# count           53902  53902.000000   53902.000000         53902.000000
# ...

# %% [markdown]
# Podemos ver que la mayoría de las llamadas son salientes y externas, podría ser por que principalmente son llamadas de clientes externos. Una cantidad muy baja de llamadas no tiene operator_id y aproximadamente el 44% de las llamadas fueron perdidas. Vemos una variabilidad en la cantidad de llamadaspor regirtro algo grande, hay llamadas de 0 segundos y otras extremadamente largas lo que indica que la presencia de outliers podrían mostrar un sesgo.

# %%
#Identificación de patrones entre variables para detección de operadores ineficientes 
resumen_operadores = df2.groupby("operator_id").agg(
    total_llamadas = ("calls_count", "sum"),
    llamadas_perdidas = ("is_missed_call", "sum"),
    llamadas_salientes = ("direction", lambda x: (x=="out").sum()),
    duracion_promedio = ("call_duration", "mean"),
    duracion_total = ("total_call_duration", "sum")
).reset_index()

resumen_operadores
# Out:
#      operator_id  total_llamadas  llamadas_perdidas  llamadas_salientes  \
# 0         879896            1131                 50                 105
# 1         879898            7974                100                 187
# 2         880020              54                  7                  14
# 3         880022             219                 33                  68
# 4         880026            2439                 94                 179
# ...          ...             ...                ...                 ...
# 1088      972412              61                  2                   4
# 1089      972460              70                  3                   7
# 1090      973120               3                  1                   2
# 1091      973286               2                  0                   0
# 1092     Unknown          113716               8050                 200
#
#       duracion_promedio  duracion_total
# 0            650.476562           97427
# ...

# %%
#% de llamadas perdidas 
resumen_operadores["porcentaje_perdidas"] = (
    resumen_operadores["llamadas_perdidas"] / resumen_operadores["total_llamadas"] * 100
)

resumen_operadores.head(20)
# Out:
#    operator_id  total_llamadas  llamadas_perdidas  llamadas_salientes  \
# 0       879896            1131                 50                 105
# 1       879898            7974                100                 187
# 2       880020              54                  7                  14
# 3       880022             219                 33                  68
# 4       880026            2439                 94                 179
# 5       880028            2906                 91                 181
# 6       880240              49                  8                  14
# 7       881278              20                  7                   8
# 8       882476               3                  0                   0
# 9       882478               4                  1                   1
# 10      882680             109                  3                   0
# 11      882684            1364                 55                 113
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(
    resumen_operadores["total_llamadas"],
    resumen_operadores["porcentaje_perdidas"],
    alpha=0.5
)
plt.xlabel("Total de llamadas")
plt.ylabel("% de llamadas perdidas")
plt.title("Relación entre volumen de llamadas y % de pérdidas")
plt.show()

# %% [markdown]
# Con este gráfico podemos interpretar que a medida que aumenta el volumen total de llamadas el porcentaje de perdidas tiende a disminuir de forma significativa, podemos deducir que existe una gran diferencia ya que entre mayor sea el número de llamadas existe una menor tasa de llamadas perdidas.

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=resumen_operadores,
    x="duracion_promedio",
    y="porcentaje_perdidas",
    alpha=0.6
)
plt.xlabel("Duración promedio de llamadas (segundos)")
plt.ylabel("% de llamadas perdidas")
plt.title("Duración promedio vs % de pérdidas")
plt.show()

# %% [markdown]
# En este gráfico podemos observar que cuando las llamadas cuentan con una duración promedio muy corta, hay una variabilidad muy grande en la cantidad de perdidas (siendo que cuando la duración promedio es 0 significa que no están completando llamadas exitosas), como en algunos casos donde se llega al 100% y con forme aumenta la diuración de las llamadas se estabiliz

# %%
resumen_operadores["porcentaje_perdidas"] = (
    resumen_operadores["llamadas_perdidas"] / resumen_operadores["total_llamadas"] * 100
)

top_perdedores = resumen_operadores.sort_values("porcentaje_perdidas", ascending=False).head(20)

import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.barh(top_perdedores["operator_id"].astype(str), top_perdedores["porcentaje_perdidas"], color="tomato")
plt.xlabel("% de llamadas perdidas")
plt.ylabel("Operator ID")
plt.title("Top 20 operadores con mayor % de llamadas perdidas")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# En este gráfico se ha desidido visualizar un rango de los elementos menos eficientes, esto muestra un factor preocupante ya que se muestra que tienen un 100% de llamadas perdidas, lo cual podría indicar una ineficiencia total. Es importamnte tomar en cuenta rangos de tiempo o algún otro factor que pueda ser un factor que provoque este resultado.

# %%
resumen_operadores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093 entries, 0 to 1092
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   operator_id          1093 non-null   object
#  1   total_llamadas       1093 non-null   int64
#  2   llamadas_perdidas    1093 non-null   int64
#  3   llamadas_salientes   1093 non-null   int64
#  4   duracion_promedio    1093 non-null   float64
#  5   duracion_total       1093 non-null   int64
#  6   porcentaje_perdidas  1093 non-null   float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 59.9+ KB

# %% [markdown]
# Dado que el volumen de datos es muy grande, el análisis se vuelve más útil si nos enfocamos en comparar a los operadores con mayor porcentaje de llamadas perdidas frente a aquellos con menor porcentaje. Esto nos permite detectar diferencias claras de desempeño y entender qué prácticas, cargas de trabajo o factores podrían estar influyendo en la eficiencia de la atención.

# %%
operadores_100 = resumen_operadores[resumen_operadores['porcentaje_perdidas'] == 100]

operadores_100.head(21)
# Out:
#      operator_id  total_llamadas  llamadas_perdidas  llamadas_salientes  \
# 27        885682               3                  3                   3
# 160       899076               2                  2                   2
# 253       905480               1                  1                   1
# 381       914272               1                  1                   1
# 386       914626               1                  1                   1
# 528       924572               1                  1                   1
# 569       928282               2                  2                   2
# 617       932246               1                  1                   1
# 687       937710               1                  1                   1
# 688       937716               1                  1                   1
# 697       937770               1                  1                   1
# 698       937772               1                  1                   1
# ...

# %%
# Contar operadores únicos
ineficientes = operadores_100["operator_id"].nunique()
print("Operadores con un total de 100% de llamadas perdidas:")
print(ineficientes)
# Out:
# Operadores con un total de 100% de llamadas perdidas:
# 21

# %% [markdown]
# Al intentar hacer una comparación de % de llamadas perdidas entre los operadores podemos percatarnos que existen un total de 21 personal con un 100% de llamadas perdidas y muy pocas llamadas en el día. de 1 a 3 llamadas, deberá ponerse una atención especial a estos operadores ya que pueden ser un factor importante de riesgo en el desempeño.

# %%
#Filtro de mejores operadores para comparación 
mejores = resumen_operadores[(resumen_operadores["porcentaje_perdidas"] <= 5) & (resumen_operadores["total_llamadas"] >= 10)]
mejores.head(21)
# Out:
#    operator_id  total_llamadas  llamadas_perdidas  llamadas_salientes  \
# 0       879896            1131                 50                 105
# 1       879898            7974                100                 187
# 4       880026            2439                 94                 179
# 5       880028            2906                 91                 181
# 10      882680             109                  3                   0
# 11      882684            1364                 55                 113
# 12      882686            3931                 88                 166
# 13      882688              82                  3                   8
# 14      882690            1766                 26                  45
# 17      883940             694                 20                  36
# 18      883942            2327                 67                 128
# 24      884478            2361                 44                  79
# ...

# %% [markdown]
# Se tomó otra muestra de 21 operadores con mejor desempeño, similar a la muestra de los peores. En este grupo se observa que algunos operadores tienen un 0% de llamadas perdidas, aunque con un volumen relativamente bajo de llamadas (no menos de 14 en total), mientras que otros manejan un gran número de llamadas con un porcentaje muy bajo de pérdidas. Esto resalta un punto clave: es necesario revisar las prácticas y factores que permiten a estos operadores mantener un desempeño tan eficiente, ya que entenderlo puede ayudar a replicar estas buenas prácticas en otros operadores.

# %%
mejores = resumen_operadores[(resumen_operadores["porcentaje_perdidas"] <= 5) & (resumen_operadores["total_llamadas"] >= 10)]

top_mejores = mejores.sort_values("total_llamadas", ascending=False).head(20)

plt.figure(figsize=(10,6))
plt.barh(top_mejores["operator_id"].astype(str), top_mejores["total_llamadas"], color="seagreen")
plt.xlabel("Total de llamadas realizadas")
plt.ylabel("Operator ID")
plt.title("Top 20 operadores más eficientes")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# Este gráfico de barras muestra el tops 20 de los empleados más eficientes.  El gráfico muestra el número de llamadas realizadas por cada operador, con los operadores 885876 y 885890 realizando la mayor cantidad de llamadas, y el operador 901880 realizando la menor cantidad de llamadas entre los 20 principales. Pero mostrando una eficiencia muy por encima que los operadores poco eficientes.

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=resumen_operadores, y="duracion_promedio")
plt.title("Distribución de duración promedio de llamadas por operador")
plt.ylabel("Duración promedio (segundos)")
plt.show()

# %% [markdown]
# El análisis de la duración promedio de llamadas por operador revela una variabilidad significativa, confirmada por la presencia de valores atípicos en la distribución. Datos estadísticos complementarios indican que la mayoría de las llamadas son salientes, pero un 44% resultan perdidas.

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=resumen_operadores, y="total_llamadas")
plt.title("Distribución del total de llamadas por operador")
plt.ylabel("Total de llamadas")
plt.show()

# %% [markdown]
# La mayoría de los operadores tienen un número relativamente bajo de llamadas, como lo indica la caja compacta cerca de la parte inferior del gráfico. Sin embargo, existen varios valores atípicos que representan a operadores con un volumen de llamadas significativamente mayor. Estos valores atípicos sugieren que algunos operadores son responsables de una gran proporción del total de llamadas realizadas. Es importante investigar las razones detrás de esta disparidad en el volumen de llamadas entre los operadores.

# %%
#mejores operadores
mejores = resumen_operadores[(resumen_operadores["porcentaje_perdidas"] <= 5) & (resumen_operadores["total_llamadas"] >= 10)]

#peores operadores
peores = resumen_operadores[resumen_operadores["porcentaje_perdidas"] == 100]

#extraer series para comparación
duracion_mejores = mejores["duracion_promedio"]
duracion_peores = peores["duracion_promedio"]

llamadas_mejores = mejores["total_llamadas"]
llamadas_peores = peores["total_llamadas"]

print("Duración promedio de llamadas (mejores operadores):\n", duracion_mejores)
print("\nDuración promedio de llamadas (peores operadores):\n", duracion_peores)
print("\nTotal de llamadas (mejores operadores):\n", llamadas_mejores)
print("\nTotal de llamadas (peores operadores):\n", llamadas_peores)
# Out:
# Duración promedio de llamadas (mejores operadores):
#  0        650.476562
# 1       1111.067729
# 4        856.939394
# 5        746.265487
# 10       136.913043
#            ...
# 1073    4190.000000
# 1084    2125.600000
# 1087     944.250000
# 1088     699.600000
# 1089     257.888889
# Name: duracion_promedio, Length: 438, dtype: float64
#
# Duración promedio de llamadas (peores operadores):
#  27      0.0
# 160     0.0
# 253     0.0
# 381     0.0
# 386     0.0
# 528     0.0
# 569     0.0
# 617     0.0
# 687     0.0
# 688     0.0
# 697     0.0
# 698     0.0
# 700     0.0
# 715     0.0
# 809     0.0
# 970     0.0
# 1011    0.0
# 1064    0.0
# 1067    0.0
# 1077    0.0
# 1080    0.0
# Name: duracion_promedio, dtype: float64
#
# Total de llamadas (mejores operadores):
#  0       1131
# 1       7974
# 4       2439
# 5       2906
# 10       109
#         ...
# 1073      29
# 1084      78
# 1087      77
# 1088      61
# 1089      70
# Name: total_llamadas, Length: 438, dtype: int64
#
# ...

# %%
from scipy.stats import ttest_ind

#comparación de duración promedio
t_stat_dur, p_val_dur = ttest_ind(duracion_mejores, duracion_peores, equal_var=False)
print("Duración promedio de llamadas:")
print(f"t-statistic: {t_stat_dur:.2f}, p-value: {p_val_dur:.4f}")

#comparación de total de llamadas
t_stat_ll, p_val_ll = ttest_ind(llamadas_mejores, llamadas_peores, equal_var=False)
print("\nTotal de llamadas:")
print(f"t-statistic: {t_stat_ll:.2f}, p-value: {p_val_ll:.4f}")
# Out:
# Duración promedio de llamadas:
# t-statistic: 16.81, p-value: 0.0000
#
# Total de llamadas:
# t-statistic: 6.82, p-value: 0.0000

# %% [markdown]
# Nuestros hallazgos proporcionan evidencia estadística que sugiere que los operadores con un menor porcentaje de llamadas perdidas tienden a completar un mayor número de llamadas y a mantener conversaciones más extensas. Esto apoya la hipótesis de que la eficiencia de un operador está positivamente correlacionada con la duración de las llamadas y el volumen de atención brindada.

# %%
#comparación visual de los mejores y peores operadores
plt.figure(figsize=(8,6))
sns.boxplot(
    x="grupo", 
    y="duracion_promedio",
    data=pd.concat([mejores.assign(grupo="Mejor"), operadores_100.assign(grupo="Peor")])
)
plt.title("Duración promedio de llamadas: Mejores vs Peores operadores")
plt.ylabel("Duración promedio (segundos)")
plt.xlabel("Grupo de operadores")
plt.show()

# %% [markdown]
# El grupo "Mejor" exhibe una duración media de llamada de aproximadamente 600-700 segundos, con un rango intercuartílico sustancial que indica una amplia distribución de la duración de las llamadas entre estos operadores. La presencia de numerosos valores atípicos, que se extienden más allá de los 14.000 segundos, destaca casos de llamadas excepcionalmente largas, que posiblemente reflejan la resolución de problemas complejos o escenarios de soporte especializado. En contraste, el grupo "Peor" demuestra una distribución muy comprimida, con el diagrama de caja colapsando cerca de cero. Esto sugiere duraciones de llamada mínimas y consistentes, con una mediana que se acerca a cero segundos, lo que indica un patrón frecuente de interacciones infructuosas o extremadamente breves. La ausencia de valores atípicos notables en este grupo refuerza la uniformidad del bajo rendimiento. Estos hallazgos visuales corroboran la diferencia estadísticamente significativa identificada a través de la prueba t, lo que respalda aún más la conclusión de que los operadores con mejor desempeño participan en interacciones con los clientes sustancialmente más largas y sostenidas en comparación con sus homólogos con peor desempeño, cuyas llamadas se caracterizan por la brevedad y una probable prevalencia de conexiones perdidas.

# %%
top_20 = resumen_operadores.nlargest(20, "total_llamadas").index
bottom_20 = resumen_operadores.nsmallest(20, "total_llamadas").index

resumen_operadores["grupo"] = "Medio"
resumen_operadores.loc[top_20, "grupo"] = "Mejor"
resumen_operadores.loc[bottom_20, "grupo"] = "Peor"

# %%
#resumen comparativo por grupo
resumen_grupos = resumen_operadores.groupby("grupo").agg({
    "duracion_promedio": ["mean", "median"],
    "total_llamadas": ["mean", "median"],
    "llamadas_perdidas": ["mean", "median"]
}).round(2)

resumen_grupos
# Out:
#       duracion_promedio          total_llamadas         llamadas_perdidas  \
#                    mean   median           mean  median              mean
# grupo
# Medio            590.31   238.30         464.62    79.0              13.7
# Mejor           4182.61  2495.96       19874.25  6814.5             457.1
# Peor             132.85    25.00           1.00     1.0               0.2
#
#
#       median
# grupo
# Medio    6.0
# Mejor   48.0
# Peor     0.0

# %%
filtros = resumen_operadores[resumen_operadores["grupo"].isin(["Mejor", "Peor"])]

plt.figure(figsize=(12,5))

# Subplot 1 - Duración promedio
plt.subplot(1,3,1)
sns.barplot(data=filtros, x="grupo", y="duracion_promedio", estimator="mean", errorbar=None)
plt.title("Duración Promedio de Llamadas")

# Subplot 2 - Total de llamadas
plt.subplot(1,3,2)
sns.barplot(data=filtros, x="grupo", y="total_llamadas", estimator="mean", errorbar=None)
plt.title("Total de Llamadas")

# Subplot 3 - Llamadas perdidas
plt.subplot(1,3,3)
sns.barplot(data=filtros, x="grupo", y="llamadas_perdidas", estimator="mean", errorbar=None)
plt.title("Llamadas Perdidas")

plt.tight_layout()
plt.show()

# %% [markdown]
# Los gráficos de barras comparan directamente la Duración Promedio de Llamadas, el Total de Llamadas y las Llamadas Perdidas entre los grupos de operadores "Mejor" y "Peor". El grupo "Mejor" exhibe una duración promedio significativamente mayor (media = 4182.61 segundos, mediana = 2495.96 segundos) y un número total de llamadas sustancialmente mayor (media = 19874.25, mediana = 6814.5) en comparación con el grupo "Peor" (Duración Promedio: media = 132.85 segundos, mediana = 25.00 segundos; Total de Llamadas: media = 1.00, mediana = 1.0). Si bien el grupo "Mejor" experimenta algunas llamadas perdidas (media = 457.1, mediana = 48.0), los valores cercanos a cero del grupo "Peor" reflejan la falta de conexiones exitosas. En resumen, los operadores "Mejor" se caracterizan por interacciones más largas, frecuentes y exitosas, mientras que los operadores "Peor" tienen dificultades para establecer conexiones significativas.

# %%
#temporalidades de desempeño por día 
df2["date"] = pd.to_datetime(df2["date"])
df2["dia_semana"] = df2["date"].dt.day_name()

desempeno_dia = df2.groupby("dia_semana").agg({
    "call_duration": "mean",
    "is_missed_call": "mean",
    "calls_count": "sum"
}).round(2)

desempeno_dia
# Out:
#             call_duration  is_missed_call  calls_count
# dia_semana
# Friday             859.63            0.43       148188
# Monday             889.74            0.43       153860
# Saturday           795.82            0.48        58778
# Sunday             814.76            0.51        41111
# Thursday           883.39            0.43       160445
# Tuesday            866.82            0.43       168557
# Wednesday          871.18            0.43       155816

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=desempeno_dia.reset_index(), x="dia_semana", y="call_duration")
plt.title("Duración promedio de llamadas por día")
plt.ylabel("Duración promedio (segundos)")
plt.xlabel("Día de la semana")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=desempeno_dia.reset_index(), x="dia_semana", y="is_missed_call", hue="dia_semana", palette="Reds", legend=False)
plt.title("% de llamadas perdidas por día")
plt.ylabel("Proporción de llamadas perdidas")
plt.xlabel("Día de la semana")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=desempeno_dia.reset_index(), x="dia_semana", y="is_missed_call", hue="dia_semana", palette="Reds", legend=False)
plt.title("% de llamadas perdidas por día")
plt.ylabel("Proporción de llamadas perdidas")
plt.xlabel("Día de la semana")
plt.xticks(rotation=45)
plt.show()

# %%
#temporalidad de desempeño por mes 
df2["mes"] = df2["date"].dt.to_period("M")

desempeño_mes = df2.groupby("mes").agg({
    "call_duration": "mean",
    "is_missed_call": "mean",
    "calls_count": "sum"
}).round(2)

desempeño_mes
# Out:
#          call_duration  is_missed_call  calls_count
# mes
# 2019-08        1281.96            0.51        41348
# 2019-09        1055.32            0.47       161821
# 2019-10         893.32            0.44       349566
# 2019-11         735.94            0.42       334020

# %%
#duración promedio de llamadas por mes
desempeño_mes = desempeño_mes.reset_index()
desempeño_mes["mes"] = desempeño_mes["mes"].dt.to_timestamp()

plt.figure(figsize=(8,5))
sns.lineplot(data=desempeño_mes, x="mes", y="call_duration", marker="o", color="blue")
plt.title("Duración promedio de llamadas por mes")
plt.ylabel("Duración promedio (segundos)")
plt.xlabel("Mes")
plt.grid(True, linestyle="--", alpha=0.6)


plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.MonthLocator())
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter("%b"))
plt.xticks(rotation=45)

plt.show()

# %%
#% de llamadas perdidas por mes
plt.figure(figsize=(8,5))
sns.lineplot(data=desempeno_mes.reset_index(), x="mes", y="is_missed_call", marker="o", color="red")
plt.title("% de llamadas perdidas por mes")
plt.ylabel("Proporción de llamadas perdidas")
plt.xlabel("Mes")
plt.grid(True, linestyle="--", alpha=0.6)
plt.show()

# %%
#volumen total de llamadas por mes
plt.figure(figsize=(8,5))
sns.barplot(data=desempeno_mes.reset_index(), x="mes", y="calls_count", hue="mes", palette="Greens", legend=False)
plt.title("Volumen total de llamadas por mes")
plt.ylabel("Número total de llamadas")
plt.xlabel("Mes")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # CONCLUSIONES
# En conclusión, nuestro análisis revela disparidades significativas en el desempeño de los operadores, divididos en grupos "Mejor" y "Peor". Los operadores "Mejor" demuestran consistentemente una mayor duración promedio de llamadas, un mayor volumen total de llamadas y, en general, interacciones más exitosas con los clientes. En contraste, los operadores ""Peor"" luchan por establecer conexiones significativas, como lo demuestra su baja duración promedio de llamadas y su escaso volumen total.
#
# ## Recomendaciones:
#
# Investigación de los "Peores" Operadores: Es imperativo investigar las causas fundamentales del bajo rendimiento de los operadores en el grupo "Peor". Esto podría implicar la evaluación de sus habilidades, la calidad de su capacitación, el acceso a herramientas adecuadas y la posible existencia de problemas técnicos que obstaculicen su capacidad para establecer conexiones efectivas.
# Análisis Comparativo de Prácticas: Se recomienda realizar un análisis comparativo exhaustivo de las prácticas de trabajo, las estrategias de comunicación y las herramientas utilizadas por los operadores "Mejor" y "Peor". El objetivo es identificar las mejores prácticas que puedan replicarse para mejorar el rendimiento de los operadores con dificultades.
# Programas de Capacitación y Desarrollo: Implementar programas de capacitación y desarrollo específicos para abordar las deficiencias identificadas en el grupo "Peor". Estos programas deben centrarse en mejorar las habilidades de comunicación, la resolución de problemas y el dominio de las herramientas y sistemas utilizados.
# Monitoreo y Retroalimentación Continua: Establecer un sistema de monitoreo continuo del desempeño de los operadores, proporcionando retroalimentación oportuna y constructiva. Esto permitirá identificar problemas emergentes y realizar ajustes en las estrategias de capacitación y apoyo según sea necesario.
# Optimización de Recursos: Evaluar la asignación de recursos y cargas de trabajo entre los operadores, asegurando que todos tengan las herramientas y el apoyo necesarios para tener éxito. Esto podría implicar la redistribución de tareas, la asignación de mentores o la provisión de asistencia técnica adicional.
#
# Al implementar estas recomendaciones, podemos aspirar a elevar el rendimiento general del equipo de operadores, mejorar la satisfacción del cliente y optimizar la eficiencia operativa.
